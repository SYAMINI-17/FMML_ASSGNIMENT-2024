# %% [markdown]
# <a href="https://colab.research.google.com/github/SYAMINI-17/FMML_ASSGNIMENT-2024/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-05-06 12:59:50--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   185MB/s    in 0.4s
#
# 2024-05-06 12:59:52 (185 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 10762   1402.0562v3  In this paper we consider the problem of onlin...  stat
# 39153   1407.5367v1  Given a set of point correspondences in two im...    cs
# 35496   0804.0066v1  Selman and Kautz's work on ``knowledge compila...    cs
# 883    1506.02256v1  Pre-training is crucial for learning deep neur...    cs
# 26559  1611.02260v1  Food fraud has been an area of great concern d...    cs
# ...             ...                                                ...   ...
# 27212  1702.08007v1  Hyperspectral imaging is an important tool in ...    cs
# 21316  1712.05247v1  This paper presents a framework for intrinsic ...    cs
# 38580   1105.4058v1  Identity verification is an increasingly impor...    cs
# 37933   1203.6452v1  Recently, a lot of effort has been paid to the...  stat
# 1050   1610.07857v1  The hybrid clustering-classification neural ne...    cs
#
#                                                    title  year  \
# 10762  Online Stochastic Optimization under Correlate...  2014
# 39153      Certifying the Existence of Epipolar Matrices  2014
# 35496  Binary Decision Diagrams for Affine Approximation  2008
# 883                      Knowledge Transfer Pre-training  2015
# 26559  Meat adulteration detection through digital im...  2016
# ...                                                  ...   ...
# 27212  Bayesian Nonparametric Unmixing of Hyperspectr...  2017
# 21316  Intrinsic Point of Interest Discovery from Tra...  2017
# 38580  Human Identity Verification based on Heart Sou...  2011
# 37933  Corrected Kriging update formulae for batch-se...  2012
# 1050   Hybrid clustering-classification neural networ...  2016
#
#                                                 keywords
# 10762  [stochastic, optimization, introduce, confiden...
# 39153  [correspondences, existence, fundamental, nece...
# 35496  [knowledge, compilation, established, approxim...
# 883    [restricted, boltzmann, structure, theoretical...
# 26559  [reduction, nutritional, consequences, regulat...
# ...                                                  ...
# 27212  [hyperspectral, important, resolution, hypersp...
# 21316  [framework, intrinsic, discovery, trajectory, ...
# 38580  [verification, increasingly, important, biomet...
# 37933  [efficient, computation, predictors, observati...
# 1050   [clustering, classification, increasing, infor...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 10762    [stochastic, optimization, introduce, confiden...
# 39153    [correspondences, existence, fundamental, nece...
# 35496    [knowledge, compilation, established, approxim...
# 883      [restricted, boltzmann, structure, theoretical...
# 26559    [reduction, nutritional, consequences, regulat...
#                                ...
# 6044     [reduction, multiclass, classification, classi...
# 11893    [structure, effective, dimensionality, paramet...
# 12558    [influence, maximization, researchers, marketi...
# 8661     [increasingly, biomedical, challenges, perform...
# 6734     [unsupervised, adaptation, prediction, exploit...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8788 words.
# Out of those 4561 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8e469360-9087-486b-93fc-7dabb649c126" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e469360-9087-486b-93fc-7dabb649c126")) {                    Plotly.newPlot(                        "8e469360-9087-486b-93fc-7dabb649c126",                        [{"x":["algorithm","preliminary","independent","reinforcement","empirical","optimization","algorithms","stochastic","dependency","distributed","introduce","challenging","correlated","identically","requiring","requirement","generating","assumption","advantage","confidence","smoothness","performance","scenarios","solvability","calibration","essential","conditions","certifying","characterize","necessary","existence","dimensional","fundamental","invariants","coordinates","represent","condition","polynomials","subspaces","determine","correspondences","efficient","considers","approximations","representation","processing","represented","computational","deduction","classical","conjunctive","knowledge","presenting","attractive","propositional","established","functions","properties","equations","approximation","presented","completeness","suggested","congruence","compilation","objective","furthermore","restricted","demonstrated","structure","recurrent","conventional","foundation","components","incrementally","theoretical","additional","experiments","boltzmann","utilizing","recognition","consuming","laboratory","aforementioned","substance","countries","regulation","traditional","detection","nutritional","techniques","histological","consequences","frequently","expensive","reduction","attention","background","promising","performances","convolutional","foreground","compensated","illustrate","available","formalize","meanwhile","technique","profitable","surveillance","framework","experimental","deploying","exploited","interesting","information","probabilistic","informative","activities","sophisticated","monitoring","summarization","observers","attentive","combining","generative","locations","inference","canonical","substantially","distribution","interactions","repulsive","repulsion","including","proposing","particles","multidimensional","identifiability","uncertainty","euclidean","applications","operations","normalization","extracted","normalized","geometric","likelihood","precisions","distances","generalization","formulated","classification","extractor","representations","propagate","embeddings","comparison","portfolio","contention","increases","instances","outperforms","configured","successful","multicore","sequential","diversify","addresses","scalability","processes","different","satisfiability","investigates","approaches","developed","perspectives","frontiers","generators","multiobjective","metaheuristics","indicator","mechanism","benchmarked","discussions","metaheuristic","distributions","implemented","component","limitations","complexity","advantages","perspective","graphical","exponential","constraint","viewpoint","importance","representational","correlation"],"y":[826,43,121,130,183,318,603,129,47,107,344,249,23,2,35,35,106,59,98,35,13,878,109,2,19,56,122,2,40,88,29,171,85,5,17,126,53,7,22,78,20,413,32,40,363,278,87,288,6,114,7,352,14,24,27,52,202,202,28,114,176,18,30,2,9,163,162,41,97,335,126,102,24,102,18,158,91,622,21,42,373,40,8,13,3,7,4,166,332,2,375,4,15,35,65,96,168,79,105,40,357,21,2,73,283,15,18,256,1,33,563,352,8,32,79,671,167,40,34,29,36,28,14,9,100,123,40,198,23,36,220,66,1,0,247,34,7,10,3,90,31,427,77,32,120,21,66,63,1,26,123,35,539,6,246,10,58,161,7,2,45,91,257,5,72,2,94,2,63,33,111,725,13,26,433,231,19,2,10,6,5,13,94,8,9,7,105,104,95,69,220,92,66,66,46,110,24,78,9,75],"type":"bar"},{"x":["algorithm","preliminary","independent","reinforcement","empirical","optimization" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4561,), (4561, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8091666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Validation</span> <span style=''>Rules</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Assessing</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.463768115942029);'>Improving</span> <span style=''>SKOS</span> <span style=''>Mapping</span> <span style=''>Quality</span> <br/><br/><span style=''>The</span> <span style=''>Simple</span> <span style='background-color:rgba(0, 255, 0, 0.3564547206165703);'>Knowledge</span> <span style='background-color:rgba(0, 255, 0, 0.6428571428571428);'>Organization</span> <span style=''>System</span> <span style=''>(SKOS)</span> <span style=''>is</span> <span style=''>popular</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.7);'>expressing</span> <span style='background-color:rgba(0, 255, 0, 0.3846153846153846);'>controlled</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>vocabularies</span> <span style=''>such</span> <span style=''>as</span> <span style=''>taxonomies</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>classifications</span> <span style=''>etc</span> <span style=''>for</span> <span style=''>their</span> <span style=''>use</span> <span style=''>in</span> <span style=''>Semantic</span> <span style=''>Web</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>Using</span> <span style=''>SKOS</span> <span style=''>concepts</span> <span style=''>can</span> <span style=''>be</span> <span style=''>linked</span> <span style=''>to</span> <span style=''>other</span> <span style=''>concepts</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.5789473684210527);'>organized</span> <span style=''>into</span> <span style='background-color:rgba(0, 255, 0, 0.3684210526315789);'>hierarchies</span> <span style=''>inside</span> <span style=''>a</span> <span style=''>single</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>terminology</span> <span style=''>system</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857143);'>Meanwhile</span> <span style='background-color:rgba(0, 255, 0, 0.7);'>expressing</span> <span style=''>mappings</span> <span style=''>between</span> <span style=''>concepts</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.32420091324200917);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>terminology</span> <span style=''>systems</span> <span style=''>is</span> <span style=''>also</span> <span style=''>possible</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.65);'>discusses</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>potential</span> <span style=''>quality</span> <span style=''>issues</span> <span style=''>in</span> <span style=''>using</span> <span style=''>SKOS</span> <span style=''>to</span> <span style=''>express</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>terminology</span> <span style=''>mappings</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Problematic</span> <span style=''>patterns</span> <span style=''>are</span> <span style=''>defined</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style=''>rules</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3807531380753139);'>automatically</span> <span style=''>detect</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>situations</span> <span style=''>where</span> <span style=''>the</span> <span style=''>mappings</span> <span style=''>either</span> <span style=''>result</span> <span style=''>in</span> <span style=''>SKOS</span> <span style='backgr ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimating</span> <span style=''>L</span> <span style=''>22</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Divergence</span> <br/><br/><span style=''>We</span> <span style=''>give</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comprehensive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterization</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>for</span> <span style=''>the</span> <span style=''>L</span> <span style=''>22</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>divergence</span> <span style=''>between</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>We</span> <span style=''>first</span> <span style=''>bound</span> <span style=''>the</span> <span style=''>rate</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>showing</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style=''>sqrtn</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style=''>provided</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>densities</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sufficiently</span> <span style=''>smooth</span> <span style=''>In</span> <span style=''>this</span> <span style=''>smooth</span> <span style=''>regime</span> <span style=''>we</span> <span style=''>then</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asymptotically</span> <span style=''>normal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construct</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asymptotic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confidence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intervals</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establish</span> <span style=''>a</span> <span style=''>Berry</span> <span style=''>Esseen</span> <span style=''>style</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inequality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterizing</span> <span style=''>the</span> <span style=''>rate</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>normality</span> <span style=''>We</span> <span style=''>also</span> <span style=''>show</span> <span style=''>that</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>is</span> <span style=''>minimax</span> <span style=''>optimal</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Reweighted</span> <span style=''>Wake</span> <span style=''>Sleep</span> <br/><br/><span style=''>Training</span> <span style=''>deep</span> <span style=''>directed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>with</span> <span style=''>many</span> <span style=''>hidden</span> <span style='background-color:rgba(255, 0, 0, 0.3220338983050848);'>variables</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performing</span> <span style='background-color:rgba(255, 0, 0, 0.3322091062394603);'>inference</span> <span style=''>remains</span> <span style=''>a</span> <span style=''>major</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>challenge</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>Helmholtz</span> <span style=''>machines</span> <span style=''>and</span> <span style=''>deep</span> <span style=''>belief</span> <span style=''>networks</span> <span style=''>are</span> <span style=''>such</span> <span style=''>models</span> <span style=''>and</span> <span style=''>the</span> <span style=''>wake</span> <span style=''>sleep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>has</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>to</span> <span style=''>train</span> <span style=''>them</span> <span style=''>The</span> <span style=''>wake</span> <span style=''>sleep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>relies</span> <span style=''>on</span> <span style=''>training</span> <span style=''>not</span> <span style=''>just</span> <span style=''>the</span> <span style=''>directed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generative</span> <span style=''>model</span> <span style=''>but</span> <span style=''>also</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generative</span> <span style=''>model</span> <span style=''>(the</span> <span style='background-color:rgba(255, 0, 0, 0.3322091062394603);'>inference</span> <span style=''>network)</span> <span style=''>that</span> <span style=''>runs</span> <span style=''>backward</span> <span style=''>from</span> <span style=''>visible</span> <span style=''>to</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6037735849056602);'>posterior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>latent</span> <span style=''>given</span> <span style=''>visible</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpretation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>wake</span> <span style=''>sleep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>suggests</span> <span style=''>that</span> <span style=''>better</span> <span style='background-color:rgba(255, 0, 0, 0.7362637362637363);'>estimators</span> <span style=''>of</span> <span style=''>the</span> <span style=''>gradient</span> <span style=''>can</span> <span style=''>be</span> <span style=''>obtained</span> <span style=''>by</span> <span style=''>sampling</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3220338983050848);'>variables</span> <span style=''>multiple</span> <span style=''>times</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3322091062394603);'>inference</span> <span style=''>network</span> <span style=''>Thi ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Multipartite</span> <span style=''>Ranking</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <span style=''>of</span> <span style=''>Low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Instances</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Supervised</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Projection</span> <span style=''>to</span> <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensional</span> <span style=''>Space</span> <br/><br/><span style=''>Pruning</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>redundant</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>irrelevant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>instances</span> <span style=''>of</span> <span style=''>data</span> <span style=''>is</span> <span style=''>a</span> <span style=''>key</span> <span style=''>to</span> <span style=''>every</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successful</span> <span style=''>solution</span> <span style=''>for</span> <span style=''>pattern</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>ranking</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>low</span> <span style=''>length</span> <span style=''>but</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>instances</span> <span style=''>Instead</span> <span style=''>of</span> <span style=''>working</span> <span style=''>in</span> <span style=''>the</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>instance</span> <span style=''>space</span> <span style=''>we</span> <span style=''>learn</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>to</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>space</span> <span style=''>spanned</span> <span style=''>by</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>classes</span> <span style=''>in</span> <span style=''>the</span> <span style=''>dataset</span> <span style=''>under</span> <span style=''>study</span> <span style=''>Imposing</span> <span style=''>higher</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distinctions</span> <span style=''>via</span> <span style=''>exposing</span> <span style=''>the</span> <span style=''>notion</span> <span style=''>of</span> <span style=''>labels</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>instances</span> <span style=''>lets</span> <span style=''>to</span> <span style=''>deploy</span> <span style=''>one</span> <span style=''>versus</span> <span style=''>all</span> <span style=''>ranking</span> <span style=''>for</span> <span style=''>each</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>classes</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selecting</span> <span style=''>quality</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>instances</span> <span style=''>via</span> <span style=''>a ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.09847679773290825)
# 	experimental (0.1246900460503011)
# 	reasoning (0.048175699610343604)
# 	segmentation (0.0669500531349628)
# 	information (0.23769040028338648)
# 	representation (0.12858660998937302)
# 	detection (0.11760538434289762)
# 	different (0.25681898689337584)
# 	convolutional (0.12646121147715197)
# 	recognition (0.13212894084307475)
#
# Some Statistics words are:
# 	variables (0.13808801213960548)
# 	theoretical (0.1471927162367223)
# 	stochastic (0.14162873039959534)
# 	statistical (0.1588265048052605)
# 	distribution (0.18361153262518967)
# 	algorithm (0.39858371269600407)
# 	estimation (0.17905918057663125)
# 	dimensional (0.18715225088517956)
# 	inference (0.19979767324228628)
# 	regression (0.18057663125948406)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="33604228-da2a-46bc-a3f7-bfdbaeb2884e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33604228-da2a-46bc-a3f7-bfdbaeb2884e")) {                    Plotly.newPlot(                        "33604228-da2a-46bc-a3f7-bfdbaeb2884e",                        [{"x":["algorithm","preliminary","independent","reinforcement","empirical","optimization","algorithms","stochastic","dependency","distributed","introduce","challenging","correlated","identically","requiring","requirement","generating","assumption","advantage","confidence","smoothness","performance","scenarios","solvability","calibration","essential","conditions","certifying","characterize","necessary","existence","dimensional","fundamental","invariants","coordinates","represent","condition","polynomials","subspaces","determine","correspondences","efficient","considers","approximations","representation","processing","represented","computational","deduction","classical","conjunctive","knowledge","presenting","attractive","propositional","established","functions","properties","equations","approximation","presented","completeness","suggested","congruence","compilation","objective","furthermore","restricted","demonstrated","structure","recurrent","conventional","foundation","components","incrementally","theoretical","additional","experiments","boltzmann","utilizing","recognition","consuming","laboratory","aforementioned","substance","countries","regulation","traditional","detection","nutritional","techniques","histological","consequences","frequently","expensive","reduction","attention","background","promising","performances","convolutional","foreground","compensated","illustrate","available","formalize","meanwhile","technique","profitable","surveillance","framework","experimental","deploying","exploited","interesting","information","probabilistic","informative","activities","sophisticated","monitoring","summarization","observers","attentive","combining","generative","locations","inference","canonical","substantially","distribution","interactions","repulsive","repulsion","including","proposing","particles","multidimensional","identifiability","uncertainty","euclidean","applications","operations","normalization","extracted","normalized","geometric","likelihood","precisions","distances","generalization","formulated","classification","extractor","representations","propagate","embeddings","comparison","portfolio","contention","increases","instances","outperforms","configured","successful","multicore","sequential","diversify","addresses","scalability","processes","different","satisfiability","investigates","approaches","developed","perspectives","frontiers","generators","multiobjective","metaheuristics","indicator","mechanism","benchmarked","discussions","metaheuristic","distributions","implemented","component","limitations","complexity","advantages","perspective","graphical","exponential","constraint","viewpoint","importance","representational","correlation","development","excellent","comparisons","distorted","additionally","distortions","indication","computationally","quantification","mathematical","decomposed","naturally","dimension","simulator","alternative","dedicated","prediction","univariate","nevertheless","versatile","estimation","compatible","associated","generalized","procedure","integrating","completely","reasonable","unrealistic","parameter","illustrated","parsimonious","relaxation","additivity","approximately","simulators","numerical","successfully","efficiency","statements","morphology","evaluation","expressions","accompanied","reporting","combinations","contribution","subjective","optimistic","decreasing","financial","decisions","semantics","linguistic","increasing","o ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	repulsion
# 	resolvable
# 	bernstein
# 	kontorovich
# 	mcallester
# 	imbalances
# 	autoimmune
# 	scleroderma
# 	reminiscent
# 	frequentist
# 	nonconvexity
# 	polyhedral
# 	trilinear
# 	endpoints
# 	tibshirani
# 	robustification
# 	elucidating
# 	minibatch
# 	degeneracy
# 	bivariate
# Some words which never appear in Statistics papers:
# 	solvability
# 	certifying
# 	deduction
# 	propositional
# 	congruence
# 	compilation
# 	substance
# 	nutritional
# 	histological
# 	observers
# 	contention
# 	multicore
# 	diversify
# 	multiobjective
# 	metaheuristics
# 	orthography
# 	argumentation
# 	defeasible
# 	dialectical
# 	multiplicity

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0496172730322345e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7575
